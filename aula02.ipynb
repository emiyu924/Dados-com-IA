# %% [markdown]
# Aula 02 - introdução ao Python e modelos de dados

# %% [markdown]
# Comparadores lógicos

# %%
print("Iniciando Notebook")
# Out:
# Iniciando Notebook

# %%
#Comparadores 
print(10 > 5) #se for verdadeiro retorna true
# Out:
# True

# %%
print(5 < 10)
# Out:
# True

# %%
idade = 10  
print(10 == 10) #realiza comparações igualdade
# Out:
# True

# %%
print(10!=11) #realiza comparações de diferenças
# Out:
# True

# %% [markdown]
# Condicionais

# %%
carga_horaria = 40 
if carga_horaria > 40: 
    print("Você precisa adquirir o uniforme")
else:
    print("Usar crachá (não precisa de uniforme)")
# Out:
# Usar crachá (não precisa de uniforme)

# %%
carga_horaria = 60 
if carga_horaria > 40: 
    print("Você precisa adquirir o uniforme")
else:
    print("Usar crachá (não precisa de uniforme)")
# Out:
# Você precisa adquirir o uniforme

# %%
#Solicitar a informação para o usuário 
carga_horaria = int(input("Digite a carga horária do seu curso:"))
if carga_horaria > 40: 
    print("Você precisa adquirir o uniforme")
else:
    print("Usar crachá (não precisa de uniforme)")
# Out:
# Usar crachá (não precisa de uniforme)

# %% [markdown]
# Programa que avalia as notas que o usuário do nosso aplicativo inseriu.

# %%
avaliacao = float(input("Digite sua avaliação: (de 0 - 10 estrelas"))
if avaliacao > 8:
    print("Nota Excelente!")
elif avaliacao > 6:
    print("Avaliação regular")
elif avaliacao > 4:
    print("Avaliação ruim!")
else:
    print("Avaliação péssima!")
# Out:
# Avaliação regular

# %% [markdown]
# Sistema que irá verificar se o filme avaliado é bom ou não
# - Criar uma variável que irá armazenar o nome do filme
# - Criar uma variável que irá armazenar a nota do filme (0 - 5)
# - Condição: Se possuir 5 estrelas, filme Vencedor do Oscar
# - Condição: se possuir de 3 a 4.99, filme Bom para assistir
# - Abaixo disso, filme não indicado

# %%
nome_filme = (input("Digite o nome do Filme a ser avaliado"))
avaliacao = float(input("Agora digite sua avaliação: (de 0 - 5 estrelas"))
if avaliacao > 5:
    print(f"Você estourou a escala de tão bom que é: {nome_filme}, parabéns para os criadores! ")
elif avaliacao == 5:
    print(f"{nome_filme} é praticamente um vencedor do Oscar, pode assistir que é sucesso!")
elif avaliacao >= 3:
    print(f"{nome_filme} é ótimo para assistir e matar o tempo!")
elif avaliacao < 0:
    print(f"{nome_filme} é tão ruim que você quer dar uma nota menor que zero, pode jogar fora")
else:
    print(f"Pode largar a tv e ir fazer outra coisa, {nome_filme} não é indicado!")
# Out:
# Pode largar a tv e ir fazer outra coisa, 0 não é indicado!

# %% [markdown]
# Estrutura de dados

# %%
#Listas 
temperatura_um = 30
temperatura_dois = 40
temperaturas = [30,40,50]
print(temperaturas[0])
print(temperaturas[1])
print(temperaturas[2])
# Out:
# 30
# 40
# 50

# %%
temperaturas[1] = 45
temperaturas[0] = 35
temperaturas[2] = 55
print(temperaturas)
# Out:
# [35, 45, 55]

# %%
temperaturas.append(60)
print(temperaturas)
# Out:
# [35, 45, 55, 60]
